# %%
import numpy as np
import pandas as pd

# %%
# %cd drive/MyDrive/AICTE project
# Out:
# /content/drive/MyDrive/AICTE project

# %%
df = pd.read_csv("HR.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df['Department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
df["Department"].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: Department, dtype: int64

# %%
df['salary'].value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.drop_duplicates(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11991 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   Work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   Department             11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Department'] = le.fit_transform(df['Department'])
df['salary'] = le.fit_transform(df['salary'])

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['satisfaction_level'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff1e154f610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff1e154fb50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff1e154e7a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff1e12900d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff1e1290370>],
#  'means': []}

# %%
import pandas as pd
import matplotlib.pyplot as plt



df1 = df.drop('salary',axis = 1)
df1 = df1.drop('Department', axis = 1)
for column in df1.columns.drop('left'):
    pd.crosstab(index=df[column], columns=df['left']).plot(kind = 'bar')

# %%
X = df.drop('left', axis = 1)
X
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 11995                0.90             0.55               3
# 11996                0.74             0.95               5
# 11997                0.85             0.54               3
# 11998                0.33             0.65               3
# 11999                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# ...

# %%
Y = df['left']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size= 0.2,random_state = 18, stratify = Y)

# %%
model1 = linear_model.LogisticRegression()
model1.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lg=model1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
scores = []
print(accuracy_score(y_test, y_pred_lg))
scores.append(accuracy_score(y_test, y_pred_lg))
# Out:
# 0.8365985827428095

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
modeltree = clf.fit(X_train,y_train)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.42427416738754326, 0.9807692307692307, 'x[0] <= 0.412\ngini = 0.277\nsamples = 9592\nvalue = [7999, 1593]'),
#  Text(0.14189554498269896, 0.9423076923076923, 'x[2] <= 0.1\ngini = 0.5\nsamples = 2269\nvalue = [1149, 1120]'),
#  Text(0.047145328719723184, 0.9038461538461539, 'x[1] <= 0.336\ngini = 0.302\nsamples = 820\nvalue = [152, 668]'),
#  Text(0.028546712802768166, 0.8653846153846154, 'x[1] <= 0.133\ngini = 0.16\nsamples = 730\nvalue = [64, 666]'),
#  Text(0.025086505190311418, 0.8269230769230769, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.03200692041522491, 0.8269230769230769, 'x[3] <= 0.138\ngini = 0.102\nsamples = 704\nvalue = [38, 666]'),
#  Text(0.028546712802768166, 0.7884615384615384, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.03546712802768166, 0.7884615384615384, 'x[3] <= 0.315\ngini = 0.07\nsamples = 691\nvalue = [25, 666]'),
#  Text(0.01903114186851211, 0.75, 'x[0] <= 0.275\ngini = 0.029\nsamples = 672\nvalue = [10, 662]'),
# ...

# %%
y_pred_dt = modeltree.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred_dt))
scores.append(accuracy_score(y_test,y_pred_dt))
# Out:
# 0.9695706544393498

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred_dt)
# Out:
# array([[1959,   42],
#        [  31,  367]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_dt)

# %%
labels =['logistic Regression', "Decision Tree"]
colors = ['red', 'blue']
plt.bar(labels,scores,color=colors,width = 0.5,align = 'center')
plt.legend(title = "Accuracy Comparision")
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.9695706544393498

# %%
f1_score(y_test,y_pred_dt)
# Out:
# 0.9095415117719952

# %%
precision_score(y_test,y_pred_dt)
# Out:
# 0.8973105134474327

# %%
recall_score(y_test,y_pred_dt)
# Out:
# 0.9221105527638191

# %%
a = classification_report(y_test,y_pred_dt)
print(a)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2001
#            1       0.90      0.92      0.91       398
#
#     accuracy                           0.97      2399
#    macro avg       0.94      0.95      0.95      2399
# weighted avg       0.97      0.97      0.97      2399
